# %%
# Install proprietary drivers
#sudo mhwd -a pci video-nvidia
# Reboot

# %%
# Install CUDA Toolkit
#sudo pacman -S cuda cudnn
# CUDA binaries should be in /opt/cuda/bin/
# Source /etc/profile or restart your session in order for the CUDA binarires to appear in the PATH.
# The default host compiler for nvcc is set by the $NVCC_CCBIN environment variable in /etc/profile.d/cuda.sh

# %%
# Update pip and setuptools
#python -m pip install -U setuptools pip

# %%
# Check CUDA version
# !nvidia-smi
# Out:
# Thu Jul  9 03:46:39 2026
# +-----------------------------------------------------------------------------------------+
# | NVIDIA-SMI 595.71.05              Driver Version: 595.71.05      CUDA Version: 13.2     |
# +-----------------------------------------+------------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id          Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |           Memory-Usage | GPU-Util  Compute M. |
# |                                         |                        |               MIG M. |
# |=========================================+========================+======================|
# |   0  NVIDIA GeForce RTX 3060 ...    Off |   00000000:01:00.0  On |                  N/A |
# | N/A   56C    P8             13W /  115W |     175MiB /   6144MiB |     24%      Default |
# |                                         |                        |                  N/A |
# ...

# %%
# Install CuPy
#pip install cupy-cuda13x; pip freeze | grep cupy

# %%
import numpy as np
import cupy as cp

# %%
x_gpu = cp.array([1, 2, 3])

# %%
x_cpu = np.array([1, 2, 3])
l2_cpu = np.linalg.norm(x_cpu)

# %%
l2_cpu
# Out:
# np.float64(3.7416573867739413)

# %%
x_gpu = cp.array([1, 2, 3])
l2_gpu = cp.linalg.norm(x_gpu)

# %%
l2_gpu
# Out:
# array(3.74165739)
